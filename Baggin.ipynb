# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafaeltafolla/MachineLearning/blob/main/Baggin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

persons = pd.read_csv("https://gist.githubusercontent.com/javierIA/7d8564f02ae92bf722800465da2d0f7a/raw/6e0b018296ba1bafe2f20319c9f3e3a8573b151e/salarios.csv")
persons
# Out:
#     edad  estudio  horas  clase_salario  valor_salario
# 0     27        9     40              0       12967.33
# 1     30        9     40              0       20171.40
# 2     42        9     40              1       39051.04
# 3     68        9     25              1       33567.25
# 4     34        8     40              0        8247.42
# ..   ...      ...    ...            ...            ...
# 95    32       13     55              0        3297.72
# 96    20       10     25              0        2266.79
# 97    46        3     40              0       17190.41
# 98    37        9     45              0         552.72
# 99    47        9     12              1       32805.86
#
# [100 rows x 5 columns]

# %%
# simular el baggin, el funcionamiento
for i in range (5):
  print(persons.sample(frac=1/10),"\n")
# Out:
#     edad  estudio  horas  clase_salario  valor_salario
# 53    64        5     40              1       30604.89
# 76    27       14     40              0        8992.67
# 99    47        9     12              1       32805.86
# 59    42        9     40              0       14209.41
# 63    23       13     30              0       11712.83
# 73    50       14     45              1       26139.60
# 9     41       10     40              0       13464.16
# 38    47        9     40              0       17935.66
# 55    30       10     40              0        5266.42
# 71    25        5     40              0       17190.41
#
#     edad  estudio  horas  clase_salario  valor_salario
# 31    45        4     10              0       16407.89
# 40    59       13     40              1       31350.14
# 45    54       13     40              1       27623.89
# 99    47        9     12              1       32805.86
# 29    59       10     40              1       26878.64
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

persons = MinMaxScaler().fit_transform(persons)
persons
# Out:
# array([[0.15873016, 0.53333333, 0.54929577, 0.        , 0.2510676 ],
#        [0.20634921, 0.53333333, 0.54929577, 0.        , 0.39675954],
#        [0.3968254 , 0.53333333, 0.54929577, 1.        , 0.77857306],
#        [0.80952381, 0.53333333, 0.33802817, 1.        , 0.66767131],
#        [0.26984127, 0.46666667, 0.54929577, 0.        , 0.15561422],
#        [0.14285714, 0.8       , 0.69014085, 0.        , 0.12572228],
#        [0.0952381 , 0.2       , 0.33802817, 0.        , 0.03466478],
#        [0.04761905, 0.6       , 0.54929577, 0.        , 0.33647331],
#        [0.06349206, 0.6       , 0.1971831 , 0.        , 0.03441342],
#        [0.38095238, 0.6       , 0.54929577, 0.        , 0.26111527],
#        [0.50793651, 0.13333333, 0.26760563, 0.        , 0.38118558],
#        [0.22222222, 0.6       , 0.54929577, 0.        , 0.1103994 ],
#        [0.77777778, 0.66666667, 0.4084507 , 1.        , 0.66779689],
#        [0.65079365, 0.53333333, 0.54929577, 1.        , 0.5173322 ],
# ...

# %%
# graficar

import matplotlib.pyplot as plt
fig=plt.figure()

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor

datos=persons.T[:-2]
clases= persons.T[3]
valor=persons.T[4]

clasificador=KNeighborsClassifier(n_neighbors=3)
regresor=KNeighborsRegressor(n_neighbors=4)

numero_de_modelos=9000

# %%
meta_class=BaggingClassifier(base_estimator=clasificador,n_estimators=numero_de_modelos,max_samples=0.30).fit(datos,clase)

meta_regres=BaggingRegressor(base_estimator=clasificador,n_estimators=numero_de_modelos,max_samples=0.30).fit(datos,clase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6b73131be7b2> in <cell line: 1>()
# ----> 1 meta_class=BaggingClassifier(base_estimator=clasificador,n_estimators=numero_de_modelos,max_samples=0.30).fit(datos,clase)
#       2
#       3 meta_regres=BaggingRegressor(base_estimator=clasificador,n_estimators=numero_de_modelos,max_samples=0.30).fit(datos,clase)
#
# NameError: name 'clase' is not defined
